# %%
import psycopg2
import pandas as pd

# %%
def create_database():
    #connect to the default database
    conn = psycopg2.connect("host=127.0.0.1 dbname=postgres user=postgres password=root")
    conn.set_session(autocommit = True)
    cur = conn.cursor()
    
    #Create the Database
    cur.execute("DROP DATABASE accounts")
    cur.execute("CREATE DATABASE accounts")
    
    #close connection to default database
    conn.close()
    
    #connect to the created accounts database
    conn = psycopg2.connect("host=127.0.0.1 dbname=accounts user=postgres password=root")
    cur = conn.cursor()
    
    return cur, conn

# %%
BankingData = pd.read_csv("banking.csv")

# %%
BankingData.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   44  blue-collar  married           basic.4y  unknown     yes   no
# 1   53   technician  married            unknown       no      no   no
# 2   28   management   single  university.degree       no     yes   no
# 3   39     services  married        high.school       no      no   no
# 4   55      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  cellular   aug         thu  ...         1    999         0  nonexistent
# 1  cellular   nov         fri  ...         1    999         0  nonexistent
# 2  cellular   jun         thu  ...         3      6         2      success
# 3  cellular   apr         fri  ...         2    999         0  nonexistent
# 4  cellular   aug         fri  ...         1      3         1      success
#
#   emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# ...

# %%
BankingData_Cleaned = BankingData[['age','job','marital','education','housing','contact']]

# %%
BankingData_Cleaned.head()
# Out:
#    age          job  marital          education housing   contact
# 0   44  blue-collar  married           basic.4y     yes  cellular
# 1   53   technician  married            unknown      no  cellular
# 2   28   management   single  university.degree     yes  cellular
# 3   39     services  married        high.school      no  cellular
# 4   55      retired  married           basic.4y     yes  cellular

# %%
FlightData = pd.read_csv("flight-data.csv")
# Out:
# C:\Users\Thusitha\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
FlightData.head()
# Out:
#    MONTH  DAY AIRLINE  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 0      1    1      AS             98      N407AS            ANC
# 1      1    1      AA           2336      N3KUAA            LAX
# 2      1    1      US            840      N171US            SFO
# 3      1    1      AA            258      N3HYAA            LAX
# 4      1    1      AS            135      N527AS            SEA
#
#   DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_DELAY  \
# 0                 SEA                    5            -11.0
# 1                 PBI                   10             -8.0
# 2                 CLT                   20             -2.0
# 3                 MIA                   20             -5.0
# 4                 ANC                   25             -1.0
#
#    SCHEDULED_ARRIVAL  ARRIVAL_DELAY
# 0                430          -22.0
# 1                750           -9.0
# 2                806            5.0
# 3                805           -9.0
# ...

# %%
FlightData_Cleaned = FlightData[['AIRLINE','FLIGHT_NUMBER','ORIGIN_AIRPORT','DESTINATION_AIRPORT']]

# %%
FlightData_Cleaned.head()
# Out:
#   AIRLINE  FLIGHT_NUMBER ORIGIN_AIRPORT DESTINATION_AIRPORT
# 0      AS             98            ANC                 SEA
# 1      AA           2336            LAX                 PBI
# 2      US            840            SFO                 CLT
# 3      AA            258            LAX                 MIA
# 4      AS            135            SEA                 ANC

# %%
WeatherData = pd.read_csv('weatherHistory.csv')

# %%
WeatherData.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     251          15.8263           0               1015.13
# ...

# %%
WeatherData_cleaned = WeatherData[['Humidity','Precip Type']]

# %%
WeatherData_cleaned.head()
# Out:
#    Humidity Precip Type
# 0      0.89        rain
# 1      0.86        rain
# 2      0.89        rain
# 3      0.83        rain
# 4      0.83        rain

# %%
BankingData_Cleaned.rename(columns = {'age':'Code1'}, inplace = True)
# Out:
# C:\Users\Thusitha\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
BankingData_Cleaned.head()
# Out:
#    Code1          job  marital          education housing   contact
# 0     44  blue-collar  married           basic.4y     yes  cellular
# 1     53   technician  married            unknown      no  cellular
# 2     28   management   single  university.degree     yes  cellular
# 3     39     services  married        high.school      no  cellular
# 4     55      retired  married           basic.4y     yes  cellular

# %%
FlightData_Cleaned.rename(columns = {'FLIGHT_NUMBER':'Code1'}, inplace = True)
# Out:
# C:\Users\Thusitha\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
FlightData_Cleaned.head()
# Out:
#   AIRLINE  Code1 ORIGIN_AIRPORT DESTINATION_AIRPORT
# 0      AS     98            ANC                 SEA
# 1      AA   2336            LAX                 PBI
# 2      US    840            SFO                 CLT
# 3      AA    258            LAX                 MIA
# 4      AS    135            SEA                 ANC

# %%
WeatherData_cleaned.rename(columns = {'Precip Type':'job'}, inplace = True)
# Out:
# C:\Users\Thusitha\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
WeatherData_cleaned.head()
# Out:
#    Humidity   job
# 0      0.89  rain
# 1      0.86  rain
# 2      0.89  rain
# 3      0.83  rain
# 4      0.83  rain

# %%
cur, conn = create_database()

# %%
BankingData_Table = ("""CREATE TABLE IF NOT EXISTS BankingDataTable(
Code1 VARCHAR ,
job VARCHAR,
marital VARCHAR,
education VARCHAR,
housing VARCHAR,
contact VARCHAR)""")

# %%
cur.execute(BankingData_Table)
conn.commit()

# %%
FlightData_Table = ("""CREATE TABLE IF NOT EXISTS FlightDataTable(
AIRLINE VARCHAR,
code1 VARCHAR,
ORIGIN_AIRPORT VARCHAR,
DESTINATION_AIRPORT VARCHAR
)""")

# %%
cur.execute(FlightData_Table)
conn.commit()

# %%
WeatherData_Table = ("""CREATE TABLE IF NOT EXISTS WeatherDataTable(
Humidity VARCHAR,
job VARCHAR)""")

# %%
cur.execute(WeatherData_Table)
conn.commit()

# %%
INSERT_INTO_BankingData_Table = ("""INSERT INTO BankingDataTable(
Code1,
job,
marital,
education,
housing,
contact) VALUES(%s,%s,%s,%s,%s,%s) """)

# %%
for i, row in BankingData_Cleaned.iterrows():
    cur.execute(INSERT_INTO_BankingData_Table,list(row))

# %%
conn.commit()

# %%
INSERT_INTO_FlightData_Table = ("""INSERT INTO FlightDataTable(
AIRLINE,
code1,
ORIGIN_AIRPORT,
DESTINATION_AIRPORT
) VALUES(%s,%s,%s,%s) """)

# %%
for i, row in FlightData_Cleaned.iterrows():
    cur.execute(INSERT_INTO_FlightData_Table,list(row))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21376/3484899952.py in <module>
#       1 for i, row in FlightData_Cleaned.iterrows():
# ----> 2     cur.execute(INSERT_INTO_FlightData_Table,list(row))
#
# ~\anaconda3\lib\encodings\utf_8.py in decode(input, errors)
#      13 encode = codecs.utf_8_encode
#      14
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_8_decode(input, errors, True)
#      17
#
# KeyboardInterrupt:

# %%
conn.commit()

# %%
INSERT_INTO_WeatherData_Table = ("""INSERT INTO WeatherDataTable(
Humidity,
job) VALUES(%s,%s) """)

# %%
for i, row in WeatherData_cleaned.iterrows():
    cur.execute(INSERT_INTO_WeatherData_Table,list(row))

# %%
conn.commit()
